# %%
# %cd ./MLP/
# Out:
# /workspace/sad_points/MLP

# %%
# %run -i ./sad_overfitting.py
# Out:
# MLP on mnist_corrupted.npz
#   0%|                                                                     | 0/300 [00:00<?, ?it/s]
#
#   0%|▏                                                            | 1/300 [00:04<21:15,  4.26s/it]
#
#   1%|▍                                                            | 2/300 [00:08<21:08,  4.26s/it]
#
#   1%|▌                                                            | 3/300 [00:12<21:03,  4.26s/it]
#
#   1%|▊                                                            | 4/300 [00:17<21:06,  4.28s/it]
#
#   2%|█                                                            | 5/300 [00:21<21:03,  4.28s/it]
#
#   2%|█▏                                                           | 6/300 [00:25<20:56,  4.27s/it]
#
#   2%|█▍                                                           | 7/300 [00:29<20:49,  4.27s/it]
#
#   3%|█▋                                                           | 8/300 [00:34<20:42,  4.26s/it]
#
# ...

# %%
plt.semilogy(loss_h)
plt.semilogy(loss_val_h)

# %%
plt.plot(acc_h)
plt.plot(acc_val_h)
