# %%
# %cd ./AlexNet/
# Out:
# /workspace/sad_points/AlexNet

# %%
# %run -i ./sad_overfitting.py
# Out:
# AlexNet on mnist_corrupted.npz
#   0%|                                                                     | 0/300 [00:00<?, ?it/s]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.semilogy(loss_h)
plt.semilogy(loss_val_h)

# %%
plt.plot(acc_h)
plt.plot(acc_val_h)
